# %% [markdown]
# # This notebook demonstrates how to access geographical data

# %%
# %matplotlib inline
from disaggregator import config, data, plot

# %% [markdown]
# ### Show underlying nuts3 data

# %% [markdown]
# ... short, in form of a dictionary:

# %%
dic_nuts3 = config.dict_region_code(keys='id_ags', values='natcode_nuts3')
dic_nuts3
# Out:
# 2025-09-25 16:15:06 disaggregator.config: WARNING  The mapping of the AGS to NUTS-3 regions is done using the file t_nuts3_lk.csv which is for a unknown year. This may not correspond entirely to the AGS number of the data fetched for another year from opendata.
# {3152000: 'DE915',
#  3156000: 'DE919',
#  1001000: 'DEF01',
#  1002000: 'DEF02',
#  1003000: 'DEF03',
#  1004000: 'DEF04',
#  1051000: 'DEF05',
#  1053000: 'DEF06',
#  9774000: 'DE278',
#  1054000: 'DEF07',
#  1055000: 'DEF08',
#  1056000: 'DEF09',
#  1057000: 'DEF0A',
#  1058000: 'DEF0B',
#  1059000: 'DEF0C',
#  1060000: 'DEF0D',
#  1061000: 'DEF0E',
#  1062000: 'DEF0F',
#  2000000: 'DE600',
#  3101000: 'DE911',
#  3102000: 'DE912',
#  3103000: 'DE913',
#  3151000: 'DE914',
#  3153000: 'DE916',
#  3154000: 'DE917',
#  3155000: 'DE918',
#  3157000: 'DE91A',
#  3158000: 'DE91B',
#  3159000: 'DE91C',
#  3241000: 'DE929',
#  3251000: 'DE922',
#  3252000: 'DE923',
#  3254000: 'DE925',
#  3255000: 'DE926',
#  3256000: 'DE927',
#  3257000: 'DE928',
#  3351000: 'DE931',
#  3352000: 'DE932',
#  3353000: 'DE933',
#  3354000: 'DE934',
#  3355000: 'DE935',
#  3356000: 'DE936',
#  3357000: 'DE937',
#  3358000: 'DE938',
#  3359000: 'DE939',
#  3360000: 'DE93A',
#  3361000: 'DE93B',
#  3401000: 'DE941',
#  3402000: 'DE942',
#  3403000: 'DE943',
#  3404000: 'DE944',
#  3405000: 'DE945',
#  3451000: 'DE946',
#  3452000: 'DE947',
#  3453000: 'DE948',
#  3454000: 'DE949',
#  3455000: 'DE94A',
#  3456000: 'DE94B',
#  3457000: 'DE94C',
#  3458000: 'DE94D',
#  3459000: 'DE94E',
#  3460000: 'DE94F',
#  3461000: 'DE94G',
#  3462000: 'DE94H',
#  4011000: 'DE501',
#  4012000: 'DE502',
#  5111000: 'DEA11',
#  5112000: 'DEA12',
#  5113000: 'DEA13',
#  5114000: 'DEA14',
#  5116000: 'DEA15',
#  5117000: 'DEA16',
#  5119000: 'DEA17',
#  5120000: 'DEA18',
#  5122000: 'DEA19',
#  5124000: 'DEA1A',
#  5154000: 'DEA1B',
#  5158000: 'DEA1C',
#  5162000: 'DEA1D',
#  5166000: 'DEA1E',
#  5170000: 'DEA1F',
#  5314000: 'DEA22',
#  5315000: 'DEA23',
#  5316000: 'DEA24',
#  5334000: 'DEA2D',
#  5358000: 'DEA26',
#  5362000: 'DEA27',
#  5366000: 'DEA28',
#  5370000: 'DEA29',
#  5374000: 'DEA2A',
#  5378000: 'DEA2B',
#  5382000: 'DEA2C',
#  5512000: 'DEA31',
#  5513000: 'DEA32',
#  5515000: 'DEA33',
#  5554000: 'DEA34',
#  5558000: 'DEA35',
#  5562000: 'DEA36',
#  5566000: 'DEA37',
#  5570000: 'DEA38',
#  5711000: 'DEA41',
#  5754000: 'DEA42',
#  5758000: 'DEA43',
#  5762000: 'DEA44',
#  5766000: 'DEA45',
#  5770000: 'DEA46',
#  5774000: 'DEA47',
#  5911000: 'DEA51',
#  5913000: 'DEA52',
#  5914000: 'DEA53',
#  5915000: 'DEA54',
#  5916000: 'DEA55',
#  5954000: 'DEA56',
#  5958000: 'DEA57',
#  5962000: 'DEA58',
#  5966000: 'DEA59',
#  5970000: 'DEA5A',
#  5974000: 'DEA5B',
#  5978000: 'DEA5C',
#  6411000: 'DE711',
#  6412000: 'DE712',
#  6413000: 'DE713',
#  6414000: 'DE714',
#  6431000: 'DE715',
#  6432000: 'DE716',
#  6433000: 'DE717',
#  6434000: 'DE718',
#  6435000: 'DE719',
#  6436000: 'DE71A',
#  6437000: 'DE71B',
#  6438000: 'DE71C',
#  6439000: 'DE71D',
#  6440000: 'DE71E',
#  6531000: 'DE721',
#  6532000: 'DE722',
#  6533000: 'DE723',
#  6534000: 'DE724',
#  6535000: 'DE725',
#  6611000: 'DE731',
#  6631000: 'DE732',
#  6632000: 'DE733',
#  6633000: 'DE734',
#  6634000: 'DE735',
#  6635000: 'DE736',
#  6636000: 'DE737',
#  7111000: 'DEB11',
#  7131000: 'DEB12',
#  7132000: 'DEB13',
#  7133000: 'DEB14',
#  7134000: 'DEB15',
#  7135000: 'DEB16',
#  7137000: 'DEB17',
#  7138000: 'DEB18',
#  7140000: 'DEB19',
#  7141000: 'DEB1A',
#  7143000: 'DEB1B',
#  7211000: 'DEB21',
#  7231000: 'DEB22',
#  7232000: 'DEB23',
#  7233000: 'DEB24',
#  7235000: 'DEB25',
#  7311000: 'DEB31',
#  7312000: 'DEB32',
#  7313000: 'DEB33',
#  7314000: 'DEB34',
#  7315000: 'DEB35',
#  7316000: 'DEB36',
#  7317000: 'DEB37',
#  7318000: 'DEB38',
#  7319000: 'DEB39',
#  7320000: 'DEB3A',
#  7331000: 'DEB3B',
#  7332000: 'DEB3C',
#  7333000: 'DEB3D',
#  7334000: 'DEB3E',
#  7335000: 'DEB3F',
#  7336000: 'DEB3G',
#  7337000: 'DEB3H',
#  7338000: 'DEB3I',
#  7339000: 'DEB3J',
#  7340000: 'DEB3K',
#  8111000: 'DE111',
#  8115000: 'DE112',
#  8116000: 'DE113',
#  8117000: 'DE114',
#  8118000: 'DE115',
#  8119000: 'DE116',
#  8121000: 'DE117',
#  8125000: 'DE118',
#  8126000: 'DE119',
#  8127000: 'DE11A',
#  8128000: 'DE11B',
#  8135000: 'DE11C',
#  8136000: 'DE11D',
#  8211000: 'DE121',
#  8212000: 'DE122',
#  8215000: 'DE123',
#  8216000: 'DE124',
#  8221000: 'DE125',
#  8222000: 'DE126',
#  8225000: 'DE127',
#  8226000: 'DE128',
#  8231000: 'DE129',
#  8235000: 'DE12A',
#  8236000: 'DE12B',
#  8237000: 'DE12C',
#  8311000: 'DE131',
#  8315000: 'DE132',
#  8316000: 'DE133',
#  8317000: 'DE134',
#  8325000: 'DE135',
#  8326000: 'DE136',
#  8327000: 'DE137',
#  8335000: 'DE138',
#  8336000: 'DE139',
#  8337000: 'DE13A',
#  8415000: 'DE141',
#  8416000: 'DE142',
#  8417000: 'DE143',
#  8421000: 'DE144',
#  8425000: 'DE145',
#  8426000: 'DE146',
#  8435000: 'DE147',
#  8436000: 'DE148',
#  8437000: 'DE149',
#  9161000: 'DE211',
#  9162000: 'DE212',
#  9163000: 'DE213',
#  9171000: 'DE214',
#  9172000: 'DE215',
#  9173000: 'DE216',
#  9174000: 'DE217',
#  9175000: 'DE218',
#  9176000: 'DE219',
#  9177000: 'DE21A',
#  9178000: 'DE21B',
#  9179000: 'DE21C',
#  9180000: 'DE21D',
#  9181000: 'DE21E',
#  9182000: 'DE21F',
#  9183000: 'DE21G',
#  9184000: 'DE21H',
#  9185000: 'DE21I',
#  9186000: 'DE21J',
#  9187000: 'DE21K',
#  9188000: 'DE21L',
#  9189000: 'DE21M',
#  9190000: 'DE21N',
#  9261000: 'DE221',
#  9262000: 'DE222',
#  9263000: 'DE223',
#  9271000: 'DE224',
#  9272000: 'DE225',
#  9273000: 'DE226',
#  9274000: 'DE227',
#  9275000: 'DE228',
#  9276000: 'DE229',
#  9277000: 'DE22A',
#  9278000: 'DE22B',
#  9279000: 'DE22C',
#  9361000: 'DE231',
#  9362000: 'DE232',
#  9363000: 'DE233',
#  9371000: 'DE234',
#  9372000: 'DE235',
#  9373000: 'DE236',
#  9374000: 'DE237',
#  9375000: 'DE238',
#  9376000: 'DE239',
#  9377000: 'DE23A',
#  9461000: 'DE241',
#  9462000: 'DE242',
#  9463000: 'DE243',
#  9464000: 'DE244',
#  9471000: 'DE245',
#  9472000: 'DE246',
#  9473000: 'DE247',
#  9474000: 'DE248',
#  9475000: 'DE249',
#  9476000: 'DE24A',
#  9477000: 'DE24B',
#  9478000: 'DE24C',
#  9479000: 'DE24D',
#  9561000: 'DE251',
#  9562000: 'DE252',
#  9563000: 'DE253',
#  9564000: 'DE254',
#  9565000: 'DE255',
#  9571000: 'DE256',
#  9572000: 'DE257',
#  9573000: 'DE258',
#  9574000: 'DE259',
#  9575000: 'DE25A',
#  9576000: 'DE25B',
#  9577000: 'DE25C',
#  9661000: 'DE261',
#  9662000: 'DE262',
#  9663000: 'DE263',
#  9671000: 'DE264',
#  9672000: 'DE265',
#  9673000: 'DE266',
#  9674000: 'DE267',
#  9675000: 'DE268',
#  9676000: 'DE269',
#  9677000: 'DE26A',
#  9678000: 'DE26B',
#  9679000: 'DE26C',
#  9761000: 'DE271',
#  9762000: 'DE272',
#  9763000: 'DE273',
#  9764000: 'DE274',
#  9771000: 'DE275',
#  9772000: 'DE276',
#  9773000: 'DE277',
#  9775000: 'DE279',
#  9776000: 'DE27A',
#  9777000: 'DE27B',
#  9778000: 'DE27C',
#  9779000: 'DE27D',
#  9780000: 'DE27E',
#  10041000: 'DEC01',
#  10042000: 'DEC02',
#  10043000: 'DEC03',
#  10044000: 'DEC04',
#  10045000: 'DEC05',
#  10046000: 'DEC06',
#  11000000: 'DE300',
#  12051000: 'DE401',
#  12052000: 'DE402',
#  12053000: 'DE403',
#  12054000: 'DE404',
#  12060000: 'DE405',
#  12061000: 'DE406',
#  12062000: 'DE407',
#  12063000: 'DE408',
#  12064000: 'DE409',
#  12065000: 'DE40A',
#  12066000: 'DE40B',
#  12067000: 'DE40C',
#  12068000: 'DE40D',
#  12069000: 'DE40E',
#  12070000: 'DE40F',
#  12071000: 'DE40G',
#  12072000: 'DE40H',
#  12073000: 'DE40I',
#  13003000: 'DE803',
#  13004000: 'DE804',
#  13071000: 'DE80J',
#  13072000: 'DE80K',
#  13073000: 'DE80L',
#  13074000: 'DE80M',
#  13075000: 'DE80N',
#  13076000: 'DE80O',
#  14511000: 'DED41',
#  14521000: 'DED42',
#  14522000: 'DED43',
#  14523000: 'DED44',
#  14524000: 'DED45',
#  14612000: 'DED21',
#  14625000: 'DED2C',
#  14626000: 'DED2D',
#  14627000: 'DED2E',
#  14628000: 'DED2F',
#  14713000: 'DED51',
#  14729000: 'DED52',
#  14730000: 'DED53',
#  15001000: 'DEE01',
#  15002000: 'DEE02',
#  15003000: 'DEE03',
#  15081000: 'DEE04',
#  15082000: 'DEE05',
#  15083000: 'DEE07',
#  15084000: 'DEE08',
#  15085000: 'DEE09',
#  15086000: 'DEE06',
#  15087000: 'DEE0A',
#  15088000: 'DEE0B',
#  15089000: 'DEE0C',
#  15090000: 'DEE0D',
#  15091000: 'DEE0E',
#  16051000: 'DEG01',
#  16052000: 'DEG02',
#  16053000: 'DEG03',
#  16054000: 'DEG04',
#  16055000: 'DEG05',
#  16056000: 'DEG0N',
#  16061000: 'DEG06',
#  16062000: 'DEG07',
#  16063000: 'DEG0P',
#  16064000: 'DEG09',
#  16065000: 'DEG0A',
#  16066000: 'DEG0B',
#  16067000: 'DEG0C',
#  16068000: 'DEG0D',
#  16069000: 'DEG0E',
#  16070000: 'DEG0F',
#  16071000: 'DEG0G',
#  16072000: 'DEG0H',
#  16073000: 'DEG0I',
#  16074000: 'DEG0J',
#  16075000: 'DEG0K',
#  16076000: 'DEG0L',
#  16077000: 'DEG0M'}

# %% [markdown]
# ... long, in form of a `pd.DataFrame`:

# %%
df_nuts3 = config.dict_region_code(raw=True)
df_nuts3.head(n=10)
# Out:
# 2025-09-25 16:15:08 disaggregator.config: WARNING  The mapping of the AGS to NUTS-3 regions is done using the file t_nuts3_lk.csv which is for a unknown year. This may not correspond entirely to the AGS number of the data fetched for another year from opendata.
#    idx  id_t_nuts3_lk  id_nuts3 natcode_nuts3                          name  \
# 0    0             21  27600021         DE915                     Göttingen
# 1    1             25  27600025         DE919              Osterode am Harz
# 2    2              1  27600001         DEF01   Flensburg, Kreisfreie Stadt
# 3    3              2  27600002         DEF02        Kiel, Kreisfreie Stadt
# 4    4              3  27600003         DEF03      Lübeck, Kreisfreie Stadt
# 5    5              4  27600004         DEF04  Neumünster, Kreisfreie Stadt
# 6    6              5  27600005         DEF05                  Dithmarschen
# 7    7              6  27600006         DEF06           Herzogtum Lauenburg
# 8    8            312  27600314         DE278                      Günzburg
# 9    9              7  27600007         DEF07                 Nordfriesland
#
#    id_ags_lk  ags_lk   id_ags
# 0         21    3152  3152000
# 1         25    3156  3156000
# 2          1    1001  1001000
# 3          2    1002  1002000
# 4          3    1003  1003000
# 5          4    1004  1004000
# 6          5    1051  1051000
# 7          6    1053  1053000
# 8        314    9774  9774000
# 9          7    1054  1054000

# %% [markdown]
# ### Show underlying geodata

# %% [markdown]
# The above shown data can be connected to polygon shapes which are available from the Rest-API. All that is done automatically within `data.database_shapes()`

# %%
gdf = data.database_shapes_gisco()
gdf.head()
# Out:
# 2025-09-25 16:18:13 disaggregator.data: INFO     Downloading shape NUTS-3 data for year 2016.
#                                        gen  \
# nuts3
# DE600                              Hamburg
# DE711          Darmstadt, Kreisfreie Stadt
# DE712  Frankfurt am Main, Kreisfreie Stadt
# DE713  Offenbach am Main, Kreisfreie Stadt
# DE714          Wiesbaden, Kreisfreie Stadt
#
#                                                 geometry
# nuts3
# DE600  MULTIPOLYGON (((560014.495 5945267.59, 560796....
# DE711  POLYGON ((480323.606 5533575.414, 480954.05 55...
# DE712  POLYGON ((462500.647 5550023.717, 462671.441 5...
# DE713  POLYGON ((482201.531 5544630.948, 482922.942 5...
# DE714  POLYGON ((445942.934 5555311.208, 448185.837 5...

# %% [markdown]
# ... and can easily be plotted:

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Plotting with many details and annotations

# %%
df_pop = data.population()
df_pop.head()
# Out:
# 2025-09-25 16:18:52 disaggregator.config: WARNING  The mapping of the AGS to NUTS-3 regions is done using the file t_nuts3_lk.csv which is for a unknown year. This may not correspond entirely to the AGS number of the data fetched for another year from opendata.
# 2025-09-25 16:18:52 disaggregator.config: WARNING  The mapping of the AGS to NUTS-3 regions is done using the file t_nuts3_lk.csv which is for a unknown year. This may not correspond entirely to the AGS number of the data fetched for another year from opendata.
# nuts3
# DE111    623738.0
# DE112    381281.0
# DE113    524127.0
# DE114    252749.0
# DE115    534074.0
# Name: value, dtype: float64

# %% [markdown]
# Plot this dataset with a high level of detail and annotations:

# %%
fig, ax = plot.choropleth_map(df_pop, figsize=(15, 35), annotate=['nuts3', 'name', 'value', 'percentage'])
# Out:
# 2025-09-25 16:18:57 disaggregator.data: INFO     Downloading shape NUTS-3 data for year 2016.
# 2025-09-25 16:19:17 disaggregator.plot: WARNING  Indices not common to both dataframes: {'DEB1D', 'DEB16', 'DEB19', 'DEB1C'}
# 2025-09-25 16:19:17 disaggregator.plot: WARNING  Indices in df but NOT in shapefile: {'DEB16', 'DEB19'}
# 2025-09-25 16:19:17 disaggregator.plot: WARNING  Indices in df but NOT in shapefile: {'DEB16', 'DEB19'}

# %% [markdown]
# ... and save it as a zoomable PDF file:

# %%
fig.savefig(config.data_out('Population_Germany_high_detail.pdf'), bbox_inches='tight')

# %% [markdown]
# Which looks zoomed like this:

# %%
from IPython.display import Image
pic = Image(filename=('./img/cutting_high_details.png'))
pic
